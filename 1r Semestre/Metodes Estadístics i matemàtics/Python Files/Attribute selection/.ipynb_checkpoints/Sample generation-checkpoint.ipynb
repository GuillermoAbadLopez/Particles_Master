# %%
# %matplotlib inline
import numpy as np
import scipy.stats as scp
import matplotlib.pylab as plt
import string

# Number of types of objects and points per type of object
Ntypes= 6
NPsample= 200
Means= []
Sigmas= []
Type= [ string.ascii_uppercase[i] for i in range(Ntypes) ]

A= [ 0 for i in range(Ntypes) ]
for i in range(Ntypes):
    mu= float(2.*i)
    sig= 1
    A[i]= scp.norm.rvs(mu,sig,NPsample)
    A[i]= np.vstack( (A[i], scp.norm.rvs(mu,sig,NPsample)) )
    A[i]= np.vstack( (A[i], scp.norm.rvs(mu,sig,NPsample)) )
    A[i]= np.vstack( (A[i], scp.norm.rvs(mu,sig,NPsample)) )
    A[i]= np.vstack( (A[i], scp.uniform.rvs(0.,1.,NPsample)) )
    A[i]= np.vstack( (A[i], scp.uniform.rvs(0.,1.,NPsample)) )
    A[i]= np.vstack( (A[i], [Type[i] for j in range(NPsample)] ) )
    A[i]= A[i].transpose()

# Save in arff format
file= open("AttSel.arff","w")
file.write("@relation AttSel\n")
file.write("\n")
for i in range(6):
    file.write("@attribute C"+str(i)+" real\n")

line="@attribute type {"
for i in range(Ntypes):
    line=line + Type[i] + ","
line= line[:-1]+"}\n\n"
file.write(line)
file.write("@data\n")

for i in range(Ntypes):
    for object in A[i]:
        line= ""
        for valor in object:
            line= line + str(valor) +","
        line= line[:-1]+"\n"
        file.write(line)               

file.close()
# Out:
# [['-1.5244785295218684' '0.912543533827233' '-0.9381381372874982' ...
#   '0.3481271361898567' '0.8034169508937992' 'A']
#  ['-0.06609120182136904' '-0.22337285560311462' '1.6432182075975568' ...
#   '0.989576317620852' '0.0486007290132453' 'A']
#  ['0.8618210924260725' '0.34363939284200706' '-0.4526791395033446' ...
#   '0.3578428171975344' '0.09022077389013139' 'A']
#  ...
#  ['0.22450321010928986' '-0.03299521732652222' '0.001380607766352868' ...
#   '0.4354517625117902' '0.33782862039847705' 'A']
#  ['0.27867151085904573' '-0.4847794947580104' '0.8818945058094375' ...
#   '0.45838553932610127' '0.6011041529573526' 'A']
#  ['-0.26828272833866584' '-0.6156418638063446' '0.6753651795049906' ...
#   '0.38276038160623227' '0.3292614199370383' 'A']]
# [['0.598849907104753' '4.997496681485797' '3.3728265242796027' ...
#   '0.34794815555321457' '0.3946462794394544' 'B']
#  ['1.5852891543719816' '-0.05529418701212885' '0.004480483031757743' ...
#   '0.058885983002566644' '0.8816912435540497' 'B']
#  ['2.820273821083555' '1.4846196585353422' '0.5310435395128019' ...
#   '0.8910109058231594' '0.3287236430879704' 'B']
#  ...
#  ['2.6190661738362486' '2.5615604584878406' '1.814378838744187' ...
#   '0.24447746914304735' '0.5678068610613672' 'B']
#  ['5.26978901863529' '1.6106675439247973' '1.2659688589697058' ...
#   '0.4119491927769383' '0.6692519767530718' 'B']
#  ['1.1675664266131565' '3.2515995675380056' '1.358766810023494' ...
#   '0.12509344544718193' '0.5773900681615028' 'B']]
# [['3.991054881835343' '3.4351881435600524' '4.881933659431748' ...
#   '0.12238996147435433' '0.18223114313285438' 'C']
#  ['3.5004051916407173' '2.454577823832471' '2.8145613158231226' ...
#   '0.4699912058471035' '0.3258210677089147' 'C']
#  ['3.5713229410396377' '5.294593959695952' '4.035261604500899' ...
#   '0.8764079474876287' '0.9691323612084146' 'C']
#  ...
#  ['4.173726538734189' '5.393385288410073' '2.940178795127525' ...
#   '0.19686785105366333' '0.026032328907008906' 'C']
#  ['4.790813008729579' '2.774867562420564' '4.46146023404948' ...
#   '0.8415801371142826' '0.12183890040734469' 'C']
#  ['2.990247077842916' '4.122488654873311' '3.152057704508616' ...
#   '0.22493987179755548' '0.8431967474046151' 'C']]
# [['6.886236386970365' '6.411361048316745' '5.131670522510117' ...
#   '0.07720068895157872' '0.5844794928119639' 'D']
#  ['6.174476106693327' '5.604192198330473' '6.505312828750643' ...
#   '0.45049961862187415' '0.47422915243979813' 'D']
#  ['6.883208454868623' '5.685036255270284' '7.057142358214927' ...
#   '0.6773040363148259' '0.37446585826025014' 'D']
#  ...
#  ['5.734735554155268' '4.808067072888964' '5.272922274009405' ...
#   '0.18310405220924542' '0.06297158557149063' 'D']
#  ['5.855824401031874' '6.570924361887675' '6.283917424690153' ...
#   '0.04249725482715028' '0.9162727356709683' 'D']
#  ['8.611847086481859' '5.804098746369492' '6.182800972595654' ...
#   '0.2818835501003999' '0.8763855937728968' 'D']]
# [['7.0159484031867585' '5.545763810389829' '9.740318829173829' ...
#   '0.6010354237537192' '0.9610847966158751' 'E']
#  ['8.777822769683976' '8.218478352748129' '6.383491064261046' ...
#   '0.6626985369863797' '0.9170976241995552' 'E']
#  ['7.240626456710141' '7.645215661074375' '7.670958321469831' ...
#   '0.7963687574822639' '0.8355646266653305' 'E']
#  ...
#  ['7.292147242203541' '7.367632574942931' '7.913404024470448' ...
#   '0.6406698480989212' '0.15562225347537217' 'E']
#  ['8.889805808330511' '7.003212939075333' '7.979479202095128' ...
#   '0.5662938046673858' '0.8686808260406264' 'E']
#  ['9.74133730546737' '7.897324562920313' '7.338447887755735' ...
#   '0.7815196534803193' '0.22347792611025896' 'E']]
# [['9.99207275066679' '10.683361491401826' '9.46209247340709' ...
#   '0.523900790637599' '0.2548988510962863' 'F']
#  ['10.066685072670584' '11.31176973164393' '9.312301836155877' ...
#   '0.2532034812897609' '0.22304967913062967' 'F']
#  ['10.488647277516945' '10.118325580190888' '7.87017247694596' ...
#   '0.6136791157950379' '0.2168819254205021' 'F']
#  ...
#  ['9.98340679586492' '9.80608560611252' '10.392023906357844' ...
#   '0.4510048737443838' '0.4867121883125367' 'F']
#  ['9.13531025891709' '10.283553103593555' '9.108427508992715' ...
#   '0.49250380683378403' '0.67023270766986' 'F']
#  ['8.661014165690013' '11.93316763575859' '10.040757609940178' ...
#   '0.9833994567526996' '0.8197650330800772' 'F']]
